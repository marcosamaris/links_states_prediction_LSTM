# %% [markdown]
# # Using the Median of $n$ buses in a period of 30 minutes

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import heapq 
import pickle
# %matplotlib inline
    
import plotnine as p9
import matplotlib.pyplot as plt
import dateutil
import datetime 

from dateutil.rrule import DAILY, rrule, MO, TU, WE, TH, FR

from sklearn.linear_model import LinearRegression, Lasso, BayesianRidge
from sklearn import tree
import math

import warnings
warnings.filterwarnings('ignore')
    

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


import sys
sys.path.append("../")

with open('../data/linhas.pkl', 'rb') as inputfile:  
    linhas = pickle.load(inputfile)

with open('../data/stops_distances_fixed10.pkl', 'rb') as input_file:
    distancias_pontos = pickle.load(input_file)
    
with open('../data/linesedges.pkl', 'rb') as input_file:
    linesedge = pickle.load(input_file)
    
with open('../data/edgeslines.pkl', 'rb') as input_file:
    edgeslines = pickle.load(input_file)

# %%
for line in range(0,len(linhas)):
# for line in range(0,1):   
    linktt = pd.DataFrame(columns=['_id', 'aproxlinkstart', 'hour', 'link', 'ltt', 
                               'month', 'travel_id', 'trip_id', 'weekday'])
    
    for iterated_link in range(0, len(linesedge[linhas[line]])):
    
#     for iterated_link in (range(0, 5)):
        with open('../../../../../GIT/smartbus/data/linktt/link-' + str(linesedge[linhas[line]][iterated_link]) + '.pkl', 'rb') as inputfile:  
            linktt_temp = pickle.load(inputfile)
            linktt = pd.concat([linktt_temp, linktt],sort=True)
            
    start_date = datetime.date(2017, 9, 1)       
    end_date = datetime.date(2017, 9, 28)  

    linktt['aproxlinkstart'] = pd.to_datetime(linktt['aproxlinkstart'], format = '%Y-%m-%d %H:%M:%S')
    linktt['day'] = pd.to_datetime(linktt['aproxlinkstart'], format = '%Y-%m-%d')
    
    linktt = linktt.loc[((linktt['aproxlinkstart'] >= start_date) &  
                     ((linktt['weekday'] == 3) |                  
                      (linktt['weekday'] == 4) | 
                      (linktt['weekday'] == 5)))
                   ]

    linktt.index = linktt['aproxlinkstart']
    
    linktt = linktt.iloc[linktt.index.indexer_between_time('08:00', '23:00')]
    
    grouped_linktt = linktt.groupby([pd.Grouper(freq='30min'), 'link', 'trip_id'], as_index=True ).median()['ltt'].unstack()\
            .rolling(1).mean().transform(lambda x: x.fillna(method='ffill')).dropna().reset_index()   
    
    for select_day in linktt.loc[linktt['aproxlinkstart'] >= end_date].aproxlinkstart.dt.strftime('%Y-%m-%d').unique():
        df_temp = linktt.loc[(linktt['aproxlinkstart'] >= select_day)]


    fig = (
            p9.ggplot(df_temp, p9.aes(x = 'factor(trip_id)', y ='ltt')) +
            p9.geom_boxplot(size=1.5) +
            p9.scale_y_continuous(limits =  (0, 150)) +        
    #         p9.stat_boxplot(geom ='errorbar')  +        
            p9.theme_bw() +
            p9.theme(figure_size = (12, 16)) +
            p9.facet_wrap('link', ncol = 6) +
            p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
            p9.theme(axis_text_x = p9.element_text(angle=90)) 
        )
    p9.ggsave(fig, 'png/Boxplot' + '_' + linhas[line] + '.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-89ab6ebaa308> in <module>
#      45             p9.theme(axis_text_x = p9.element_text(angle=90))
#      46         )
# ---> 47     p9.ggsave(fig, 'png/Boxplot' + '_' + linhas[line] + '.png')
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/ggplot.py in ggsave(plot, *arg, **kwargs)
#     737     Use :meth:`ggplot.save` instead
#     738     """
# --> 739     return plot.save(*arg, **kwargs)
#     740
#     741
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/ggplot.py in save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     723
#     724         try:
# --> 725             _save()
#     726         except Exception as err:
#     727             figure[0] and plt.close(figure[0])
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/ggplot.py in _save()
#     709         # Helper function so that we can clean up when it fails
#     710         def _save():
# --> 711             fig = figure[0] = self.draw()
#     712
#     713             # savefig ignores the figure face & edge colors
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/ggplot.py in draw(self, return_ggplot)
#     186         # new frames knowing that they are separate from the original.
#     187         with pd.option_context('mode.chained_assignment', None):
# --> 188             return self._draw(return_ggplot)
#     189
#     190     def _draw(self, return_ggplot=False):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     206                 self._resize_panels()
#     207                 # Drawing
# --> 208                 self._draw_layers()
#     209                 self._draw_facet_labels()
#     210                 self._draw_labels()
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/ggplot.py in _draw_layers(self)
#     391         """
#     392         # Draw the geoms
# --> 393         self.layers.draw(self.layout, self.coordinates)
#     394
#     395     def _draw_facet_labels(self):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/layer.py in draw(self, layout, coord)
#      74         for i, l in enumerate(self, start=1):
#      75             l.zorder = i
# ---> 76             l.draw(layout, coord)
#      77
#      78     def compute_aesthetics(self, plot):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/layer.py in draw(self, layout, coord)
#     450         # At this point each layer must have the data
#     451         # that is created by the plot build process
# --> 452         self.geom.draw_layer(self.data, layout, coord, **params)
#     453
#     454     def use_defaults(self, data=None):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/geoms/geom.py in draw_layer(self, data, layout, coord, **params)
#     219             panel_params = layout.panel_params[ploc]
#     220             ax = layout.axs[ploc]
# --> 221             self.draw_panel(pdata, panel_params, coord, ax, **params)
#     222
#     223     def draw_panel(self, data, panel_params, coord, ax, **params):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/geoms/geom.py in draw_panel(self, data, panel_params, coord, ax, **params)
#     254         for _, gdata in data.groupby('group'):
#     255             gdata.reset_index(inplace=True, drop=True)
# --> 256             self.draw_group(gdata, panel_params, coord, ax, **params)
#     257
#     258     @staticmethod
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/geoms/geom_boxplot.py in draw_group(data, panel_params, coord, ax, **params)
#     147             outliers['stroke'] = outlier_value('stroke')
#     148             geom_point.draw_group(outliers, panel_params,
# --> 149                                   coord, ax, **params)
#     150
#     151         # plot
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/geoms/geom_point.py in draw_group(data, panel_params, coord, ax, **params)
#      27     @staticmethod
#      28     def draw_group(data, panel_params, coord, ax, **params):
# ---> 29         data = coord.transform(data, panel_params)
#      30         units = 'shape'
#      31         for _, udata in groupby_with_null(data, units):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/coords/coord_cartesian.py in transform(self, data, panel_params, munch)
#      37             return squish_infinite(data, range=panel_params['y_range'])
#      38
# ---> 39         return transform_position(data, squish_infinite_x, squish_infinite_y)
#      40
#      41     def setup_panel_params(self, scale_x, scale_y):
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/positions/position.py in transform_position(data, trans_x, trans_y)
#      95         if trans_x:
#      96             xs = [name for name in data.columns if name in X]
# ---> 97             data[xs] = data[xs].apply(trans_x)
#      98
#      99         if trans_y:
#
# ~/tensorflow/lib/python3.5/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~/tensorflow/lib/python3.5/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~/tensorflow/lib/python3.5/site-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# ~/tensorflow/lib/python3.5/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# ~/tensorflow/lib/python3.5/site-packages/plotnine/coords/coord_cartesian.py in squish_infinite_x(data)
#      32     def transform(self, data, panel_params, munch=False):
#      33         def squish_infinite_x(data):
# ---> 34             return squish_infinite(data, range=panel_params['x_range'])
#      35
#      36         def squish_infinite_y(data):
#
# ~/tensorflow/lib/python3.5/site-packages/mizani/bounds.py in squish_infinite(x, range)
#     219         x = np.asarray(x)
#     220
# --> 221     x[x == -np.inf] = range[0]
#     222     x[x == np.inf] = range[1]
#     223
#
# ~/tensorflow/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/tensorflow/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#    1646             method = getattr(x, op_name, None)
#    1647             if method is not None:
# -> 1648                 with np.errstate(all='ignore'):
#    1649                     result = method(y)
#    1650                 if result is NotImplemented:
#
# ~/tensorflow/lib/python3.5/site-packages/numpy/core/numeric.py in __enter__(self)
#    3056         self.kwargs = kwargs
#    3057
# -> 3058     def __enter__(self):
#    3059         self.oldstate = seterr(**self.kwargs)
#    3060         if self.call is not _Unspecified:
#
# KeyboardInterrupt:

# %%
for line in range(0,len(linhas)):
# for line in range(0,1):   
    linktt = pd.DataFrame(columns=['_id', 'aproxlinkstart', 'hour', 'link', 'ltt', 
                               'month', 'travel_id', 'trip_id', 'weekday'])
    
    for iterated_link in range(0, len(linesedge[linhas[line]])):
    
#     for iterated_link in (range(0, 5)):
        with open('../../../../../GIT/smartbus/data/linktt/link-' + str(linesedge[linhas[line]][iterated_link]) + '.pkl', 'rb') as inputfile:  
            linktt_temp = pickle.load(inputfile)
            linktt = pd.concat([linktt_temp, linktt],sort=True)
            
    start_date = datetime.date(2017, 9, 1)       
    end_date = datetime.date(2017, 9, 28)  

    linktt['aproxlinkstart'] = pd.to_datetime(linktt['aproxlinkstart'], format = '%Y-%m-%d %H:%M:%S')
    linktt['day'] = pd.to_datetime(linktt['aproxlinkstart'], format = '%Y-%m-%d')
    
    linktt = linktt.loc[((linktt['aproxlinkstart'] >= start_date) &  
                     ((linktt['weekday'] == 3) |                  
                      (linktt['weekday'] == 4) | 
                      (linktt['weekday'] == 5)))
                   ]

    linktt.index = linktt['aproxlinkstart']
    
    linktt = linktt.iloc[linktt.index.indexer_between_time('08:00', '23:00')]
    
    grouped_linktt = linktt.groupby([pd.Grouper(freq='30min'), 'link', 'trip_id'], as_index=True ).median()['ltt'].unstack()\
            .rolling(1).mean().transform(lambda x: x.fillna(method='ffill')).dropna().reset_index()   
    
    for select_day in linktt.loc[linktt['aproxlinkstart'] >= end_date].aproxlinkstart.dt.strftime('%Y-%m-%d').unique():
        df_temp = linktt.loc[(linktt['aproxlinkstart'] >= select_day)]


    fig = (
            p9.ggplot(df_temp, p9.aes(x = 'factor(trip_id)', y ='ltt')) +
            p9.geom_boxplot(size=1.25, outlier_size=1.25) +
#             p9.scale_y_continuous(limits =  (0, 150)) +        
    #         p9.stat_boxplot(geom ='errorbar')  +        
            p9.theme_bw() +
            p9.theme(figure_size = (12, 16)) +
            p9.facet_wrap('link', ncol = 6, scales='free_y') +
            p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
            p9.theme(axis_text_x = p9.element_text(angle=90)) 
        )
    print(linhas[line])
    p9.ggsave(fig, 'png/Boxplot' + '_' + linhas[line] + '_outliers.png')
# Out:
# 2005-10-0
# 2016-10-0
# 2031-10-0
# 2058-10-1
# 2076-10-0
# 2080-10-0
# 2088-10-0
# 213C-10-1
# 213C-31-1
# 2626-10-0
# 263C-10-1
# 2666-10-0
# 2666-21-0
# 2678-10-0
# 2678-41-0
# 2721-10-0
# 273D-10-0
# 273N-41-0
# 273X-10-0
# 2766-10-0
# 2766-41-0
# 2772-10-0
# 2780-10-0
# 3001-10-0
# 3002-10-0
# 307C-10-0
# 312N-10-0
# 3459-10-0
# 3459-24-0
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-12-5dc273cd0819> in <module>
#       8 #     for iterated_link in (range(0, 5)):
#       9         with open('../../../../../GIT/smartbus/data/linktt/link-' + str(linesedge[linhas[line]][iterated_link]) + '.pkl', 'rb') as inputfile:
# ---> 10             linktt_temp = pickle.load(inputfile)
#      11             linktt = pd.concat([linktt_temp, linktt],sort=True)
#      12
#
# EOFError: Ran out of input

# %%
linktt.loc[(linktt['aproxlinkstart'] >= select_day) &
] 
            

fig = (
        p9.ggplot(df_temp, p9.aes(x = 'hour', y ='ltt', group='hour', colors='hour')) +
        p9.geom_boxplot() +
        p9.scale_y_continuous(limits =  (0, 150)) +        
        p9.stat_boxplot(geom ='errorbar')  +        
        p9.theme_bw() +
        p9.theme(figure_size = (8, 12)) +
        p9.facet_wrap('~trip_id', ncol = 6) +
        p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
        p9.theme(figure_size = (9, 12)) +
        p9.theme(axis_text_x = p9.element_text(angle=90)) 
    )
p9.ggsave(fig, 'png/Boxplot' + '_' + select_day + '.png')
# Out:
# [(3876, 3877),
#  (3877, 3878),
#  (3878, 3879),
#  (3879, 3880),
#  (3880, 3881),
#  (3881, 3882),
#  (3882, 3883),
#  (3883, 3884),
#  (3884, 3885),
#  (3885, 3886),
#  (3886, 3887),
#  (3887, 3888),
#  (3888, 3889),
#  (3889, 3890),
#  (3890, 3891),
#  (3891, 3892),
#  (3892, 3893),
#  (3893, 3894),
#  (3894, 3895),
#  (3895, 3896),
#  (3896, 3897),
#  (3897, 3898),
#  (3898, 3899),
#  (3899, 3900),
#  (3900, 3901),
#  (3901, 3902),
#  (3902, 3903),
#  (3903, 955),
#  (955, 956),
#  (956, 957),
#  (957, 958),
#  (958, 3904),
#  (3904, 1063),
#  (1063, 955),
#  (955, 1064),
#  (1064, 1065),
#  (1065, 3905),
#  (3905, 3906),
#  (3906, 3907),
#  (3907, 3908),
#  (3908, 3909),
#  (3909, 3910),
#  (3910, 3911),
#  (3911, 3912),
#  (3912, 3913),
#  (3913, 3914),
#  (3914, 3915),
#  (3915, 3916),
#  (3916, 3917),
#  (3917, 3918),
#  (3918, 3919),
#  (3919, 3920),
#  (3920, 3921),
#  (3921, 3922)]

# %%
MAPE_day = []
    
for select_day in linktt.loc[linktt['aproxlinkstart'] >= end_date].aproxlinkstart.dt.strftime('%Y-%m-%d').unique():
    
    for link in range(1, len(linesedge[linhas[line]])-2):
#     for link in range(2, 7):
        df_temp = linktt.loc[(linktt['aproxlinkstart'] >= select_day) & 
                             (linktt['link'] == str(linesedge[linhas[line]][link]))
                            ]
    
        travels_day = np.unique(np.array(df_temp['travel_id']))

        for hour_day in range(480, 1260, 30):   
            int_part, float_part = divmod((hour_day/60), 1)

            if float_part != 0:
                hour_begin = str(int(int_part)) + ':' + '30'
                hour_end = str(int(int_part + 1 )) + ':' + '00'
                hour_test = str(int(int_part + 1 )) + ':' + '30'
                hour_future = str(int(int_part + 2 )) + ':' + '00'
            else:
                hour_begin = str(int(int_part)) + ':' + '00'
                hour_end = str(int(int_part)) + ':' + '30'
                hour_test = str(int(int_part + 1 )) + ':' + '00'
                hour_future = str(int(int_part + 1 )) + ':' + '30'

            df_temp_time = df_temp.iloc[df_temp.index.indexer_between_time( hour_begin, hour_end)]
            df_temp_test = df_temp.iloc[df_temp.index.indexer_between_time( hour_end, hour_test)]
            df_temp_future = df_temp.iloc[df_temp.index.indexer_between_time(hour_test, hour_future)]
            
            ### Temporal Link travel time used in the median (us) 
            temp_travels_time = df_temp_time['ltt']
            time_tests        = df_temp_test['ltt']
            time_future       = df_temp_future['ltt']
            

            median_test = np.mean(temp_travels_time)                
           
            if ((len(temp_travels_time) > 0) & (math.isnan(median_test) == False)):
                MAPE_day.append([line, link, select_day, hour_begin + ' - ' + hour_end, len(temp_travels_time), 
                                 median_test, 
                                 mean_absolute_percentage_error([median_test]*len(temp_travels_time), temp_travels_time), 
                                 str(np.array(temp_travels_time)), 
                                 'Actual'])
                    
                MAPE_day.append([line, link, select_day, hour_end + ' - ' + hour_test, len(time_tests), 
                                 median_test,
                                 mean_absolute_percentage_error([median_test]*len(time_tests), time_tests), 
                                 str(np.array(time_tests)), 
                                 'After'])
                    
                MAPE_day.append([line, link, select_day, hour_test + ' - ' + hour_future, len(time_future), median_test,
                                     mean_absolute_percentage_error([median_test]*len(time_future), time_future), 
                                     str(np.array(time_future)), 'Future'])

                
data = pd.DataFrame(MAPE_day,columns=['line', 'link', 'day', 'time', 'N-travel', 'median', 'MAPE', 
                                      'travels_time', 'errors'])
# data = data.loc[data['MAPE'] != 0] 

pd.DataFrame(data).to_html('html/data-30M_mean_'  + select_day + '.html')  
        
# data = data.loc[data['MAPE'] != 0]

# data.loc[(data['errors'] != 'median_LR_after') & (data['errors'] != 'median_Tree_after') &
#         (data['errors'] != 'median_LR_future') & (data['errors'] != 'median_Tree_future')]

fig = (
        p9.ggplot(data, p9.aes(x = 'errors', y ='MAPE', group='errors', colors='errors')) +
        p9.geom_boxplot( outlier_shape = "") +
#         p9.scale_y_continuous(limits =  (0, 50)) +        
        p9.stat_boxplot(geom ='errorbar')  +        
        p9.theme_bw() +
        p9.theme(figure_size = (8, 12)) +
        p9.facet_wrap('~line', ncol = 3) +
        p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
        p9.theme(figure_size = (9, 12)) +
        p9.theme(axis_text_x = p9.element_text(angle=90)) 
    )
p9.ggsave(fig, 'png/Boxplot' + '_' + select_day + '_30M_mean.png')  
p9.ggsave(fig, 'pdf/Boxplot' + '_' + select_day + '_30M_mean.pdf')  


for i in data['errors'].unique():
    print(i + ' : ' + str(data.loc[data['errors'] == i]['MAPE'].mean()))
# Out:
# Actual : 31.874030015372625
# After : 291.6129596409533
# Future : 189.0730073025666

# %% [markdown]
# # Using the Median of $n$ buses in a period of 60 minutes

# %%
# for line in range(0,len(linhas)):
for line in range(0,1):   
    linktt = pd.DataFrame(columns=['_id', 'aproxlinkstart', 'hour', 'link', 'ltt', 
                               'month', 'travel_id', 'trip_id', 'weekday'])
    
    for iterated_link in range(0, len(linesedge[linhas[line]])):
    
#     for iterated_link in (range(0, 5)):
        with open('../data/linktt/link-' + str(linesedge[linhas[line]][iterated_link]) + '.pkl', 'rb') as inputfile:  
            linktt_temp = pickle.load(inputfile)
            linktt = pd.concat([linktt_temp, linktt],sort=True)
            
    start_date = datetime.date(2017, 9, 1)       
    end_date = datetime.date(2017, 9, 28)  

    linktt['aproxlinkstart'] = pd.to_datetime(linktt['aproxlinkstart'], format = '%Y-%m-%d %H:%M:%S')
    linktt['day'] = pd.to_datetime(linktt['aproxlinkstart'], format = '%Y-%m-%d')
    
    linktt = linktt.loc[((linktt['aproxlinkstart'] >= start_date) &  
                     ((linktt['weekday'] == 3) |                  
                      (linktt['weekday'] == 4) | 
                      (linktt['weekday'] == 5)))
                   ]

    linktt.index = linktt['aproxlinkstart']
    
    linktt = linktt.iloc[linktt.index.indexer_between_time('08:00', '23:00')]
    
    grouped_linktt = linktt.groupby([pd.Grouper(freq='60min'), 'link'], as_index=True ).median()['ltt'].unstack()\
            .rolling(1).mean().transform(lambda x: x.fillna(method='ffill')).dropna().reset_index()    

    
    
MAPE_day = []
    
for select_day in linktt.loc[linktt['aproxlinkstart'] >= end_date].aproxlinkstart.dt.strftime('%Y-%m-%d').unique():
    
    for link in range(1, len(linesedge[linhas[line]])-2):
#     for link in range(2, 7):
        df_temp = linktt.loc[(linktt['aproxlinkstart'] >= select_day) & 
                             (linktt['link'] == str(linesedge[linhas[line]][link]))
                            ]
    
        travels_day = np.unique(np.array(df_temp['travel_id']))

        for hour_day in range(480, 1260, 30):   
            int_part, float_part = divmod((hour_day/60), 1)

            if float_part != 0:
                hour_begin = str(int(int_part)) + ':' + '30'
                hour_end = str(int(int_part + 1 )) + ':' + '00'
                hour_test = str(int(int_part + 1 )) + ':' + '30'
                hour_future = str(int(int_part + 2 )) + ':' + '00'
            else:
                hour_begin = str(int(int_part)) + ':' + '00'
                hour_end = str(int(int_part)) + ':' + '30'
                hour_test = str(int(int_part + 1 )) + ':' + '00'
                hour_future = str(int(int_part + 1 )) + ':' + '30'

            df_temp_time = df_temp.iloc[df_temp.index.indexer_between_time( hour_begin, hour_end)]
            df_temp_test = df_temp.iloc[df_temp.index.indexer_between_time( hour_end, hour_test)]
            df_temp_future = df_temp.iloc[df_temp.index.indexer_between_time(hour_test, hour_future)]
            
            ### Temporal Link travel time used in the median (us) 
            temp_travels_time = df_temp_time['ltt']
            time_tests        = df_temp_test['ltt']
            time_future       = df_temp_future['ltt']
            

            median_test = np.median(temp_travels_time)                
           
            if ((len(temp_travels_time) > 0) & (math.isnan(median_test) == False)):
                MAPE_day.append([line, link, select_day, hour_begin + ' - ' + hour_end, len(temp_travels_time), 
                                 median_test, 
                                 mean_absolute_percentage_error([median_test]*len(temp_travels_time), temp_travels_time), 
                                 str(np.array(temp_travels_time)), 
                                 'Actual'])
                    
                MAPE_day.append([line, link, select_day, hour_end + ' - ' + hour_test, len(time_tests), 
                                 median_test,
                                 mean_absolute_percentage_error([median_test]*len(time_tests), time_tests), 
                                 str(np.array(time_tests)), 
                                 'After'])
                    
                MAPE_day.append([line, link, select_day, hour_test + ' - ' + hour_future, len(time_future), median_test,
                                     mean_absolute_percentage_error([median_test]*len(time_future), time_future), 
                                     str(np.array(time_future)), 'Future'])

                
data = pd.DataFrame(MAPE_day,columns=['line', 'link', 'day', 'time', 'N-travel', 'median', 'MAPE', 
                                      'travels_time', 'errors'])
# data = data.loc[data['MAPE'] != 0] 

pd.DataFrame(data).to_html('html/data-30M_median_'  + select_day + '.html')  
        
# data = data.loc[data['MAPE'] != 0]

# data.loc[(data['errors'] != 'median_LR_after') & (data['errors'] != 'median_Tree_after') &
#         (data['errors'] != 'median_LR_future') & (data['errors'] != 'median_Tree_future')]

fig = (
        p9.ggplot(data, p9.aes(x = 'errors', y ='MAPE', group='errors', colors='errors')) +
        p9.geom_boxplot( outlier_shape = "") +
#         p9.scale_y_continuous(limits =  (0, 50)) +        
        p9.stat_boxplot(geom ='errorbar')  +        
        p9.theme_bw() +
        p9.theme(figure_size = (8, 12)) +
        p9.facet_wrap('~line', ncol = 3) +
        p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
        p9.theme(figure_size = (9, 12)) +
        p9.theme(axis_text_x = p9.element_text(angle=90)) 
    )
p9.ggsave(fig, 'png/Boxplot' + '_' + select_day + '_30M_median.png')  
p9.ggsave(fig, 'pdf/Boxplot' + '_' + select_day + '_30M_median.pdf')  


for i in data['errors'].unique():
    print(i + ' : ' + str(data.loc[data['errors'] == i]['MAPE'].mean()))
# Out:
# Actual : 52.73548280974722
# After : 323.4832612215392
# Future : 261.7892941970716

# %%
MAPE_day = []
    
for select_day in linktt.loc[linktt['aproxlinkstart'] >= end_date].aproxlinkstart.dt.strftime('%Y-%m-%d').unique():
    
    for link in range(1, len(linesedge[linhas[line]])-2):
#     for link in range(2, 7):
        df_temp = linktt.loc[(linktt['aproxlinkstart'] >= select_day) & 
                             (linktt['link'] == str(linesedge[linhas[line]][link]))
                            ]
    
        travels_day = np.unique(np.array(df_temp['travel_id']))

        for hour_day in range(640, 1200, 60):   
            int_part, float_part = divmod((hour_day/60), 1)

            hour_begin = str(int(int_part)) + ':' + '00'
            hour_end = str(int(int_part + 1 )) + ':' + '00'
            hour_test = str(int(int_part +  2)) + ':' + '00'
            hour_future = str(int(int_part +  3)) + ':' + '00'
                
            df_temp_time = df_temp.iloc[df_temp.index.indexer_between_time( hour_begin, hour_end)]
            df_temp_test = df_temp.iloc[df_temp.index.indexer_between_time( hour_end, hour_test)]
            df_temp_future = df_temp.iloc[df_temp.index.indexer_between_time(hour_test, hour_future)]
            
            ### Temporal Link travel time used in the median (us) 
            temp_travels_time = df_temp_time['ltt']
            time_tests        = df_temp_test['ltt']
            time_future       = df_temp_future['ltt']
            

            median_test = np.median(temp_travels_time)                
           
            if ((len(temp_travels_time) > 0) & (math.isnan(median_test) == False)):
                MAPE_day.append([line, link, select_day, hour_begin + ' - ' + hour_end, len(temp_travels_time), 
                                 median_test, 
                                 mean_absolute_percentage_error([median_test]*len(temp_travels_time), temp_travels_time), 
                                 str(np.array(temp_travels_time)), 
                                 'Actual'])
                    
                MAPE_day.append([line, link, select_day, hour_end + ' - ' + hour_test, len(time_tests), 
                                 median_test,
                                 mean_absolute_percentage_error([median_test]*len(time_tests), time_tests), 
                                 str(np.array(time_tests)), 
                                 'After'])
                    
                MAPE_day.append([line, link, select_day, hour_test + ' - ' + hour_future, len(time_future), median_test,
                                     mean_absolute_percentage_error([median_test]*len(time_future), time_future), 
                                     str(np.array(time_future)), 'Future'])

                
data = pd.DataFrame(MAPE_day,columns=['line', 'link', 'day', 'time', 'N-travel', 'median', 'MAPE', 
                                      'travels_time', 'errors'])
# data = data.loc[data['MAPE'] != 0] 

pd.DataFrame(data).to_html('html/data-60M_median_'  + select_day + '.html')  
        
# data = data.loc[data['MAPE'] != 0]

# data.loc[(data['errors'] != 'median_LR_after') & (data['errors'] != 'median_Tree_after') &
#         (data['errors'] != 'median_LR_future') & (data['errors'] != 'median_Tree_future')]

fig = (
        p9.ggplot(data, p9.aes(x = 'errors', y ='MAPE', group='errors', colors='errors')) +
        p9.geom_boxplot( outlier_shape = True) +
#         p9.scale_y_continuous(limits =  (0, 50)) +        
        p9.stat_boxplot(geom ='errorbar')  +        
        p9.theme_bw() +
        p9.theme(figure_size = (8, 12)) +
        p9.facet_wrap('~line', ncol = 3) +
        p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
        p9.theme(figure_size = (9, 12)) +
        p9.theme(axis_text_x = p9.element_text(angle=90)) 
    )
p9.ggsave(fig, 'png/Boxplot' + '_' + select_day + '_60M_median.png')  
p9.ggsave(fig, 'pdf/Boxplot' + '_' + select_day + '_60M_median.pdf')  


for i in data['errors'].unique():
    print(i + ' : ' + str(data.loc[data['errors'] == i]['MAPE'].mean()))
# Out:
# Actual : 74.17979711597515
# After : 240.39314054730067
# Future : 228.67733402364792

# %%
MAPE_day = []
    
for select_day in linktt.loc[linktt['aproxlinkstart'] >= end_date].aproxlinkstart.dt.strftime('%Y-%m-%d').unique():
    
    for link in range(1, len(linesedge[linhas[line]])-2):
#     for link in range(2, 7):
        df_temp = linktt.loc[(linktt['aproxlinkstart'] >= select_day) & 
                             (linktt['link'] == str(linesedge[linhas[line]][link]))
                            ]
    
        travels_day = np.unique(np.array(df_temp['travel_id']))

        for hour_day in range(640, 1200, 60):   
            int_part, float_part = divmod((hour_day/60), 1)

            hour_begin = str(int(int_part)) + ':' + '00'
            hour_end = str(int(int_part + 1 )) + ':' + '00'
            hour_test = str(int(int_part +  2)) + ':' + '00'
            hour_future = str(int(int_part +  3)) + ':' + '00'
                
            df_temp_time = df_temp.iloc[df_temp.index.indexer_between_time( hour_begin, hour_end)]
            df_temp_test = df_temp.iloc[df_temp.index.indexer_between_time( hour_end, hour_test)]
            df_temp_future = df_temp.iloc[df_temp.index.indexer_between_time(hour_test, hour_future)]
            
            ### Temporal Link travel time used in the median (us) 
            temp_travels_time = df_temp_time['ltt']
            time_tests        = df_temp_test['ltt']
            time_future       = df_temp_future['ltt']
            

            median_test = np.mean(temp_travels_time)                
           
            if ((len(temp_travels_time) > 0) & (math.isnan(median_test) == False)):
                MAPE_day.append([line, link, select_day, hour_begin + ' - ' + hour_end, len(temp_travels_time), 
                                 median_test, 
                                 mean_absolute_percentage_error([median_test]*len(temp_travels_time), temp_travels_time), 
                                 str(np.array(temp_travels_time)), 
                                 'Actual'])
                    
                MAPE_day.append([line, link, select_day, hour_end + ' - ' + hour_test, len(time_tests), 
                                 median_test,
                                 mean_absolute_percentage_error([median_test]*len(time_tests), time_tests), 
                                 str(np.array(time_tests)), 
                                 'After'])
                    
                MAPE_day.append([line, link, select_day, hour_test + ' - ' + hour_future, len(time_future), median_test,
                                     mean_absolute_percentage_error([median_test]*len(time_future), time_future), 
                                     str(np.array(time_future)), 'Future'])

                
data = pd.DataFrame(MAPE_day,columns=['line', 'link', 'day', 'time', 'N-travel', 'median', 'MAPE', 
                                      'travels_time', 'errors'])
# data = data.loc[data['MAPE'] != 0] 

pd.DataFrame(data).to_html('html/data-60M_mean_'  + select_day + '.html')  
        
# data = data.loc[data['MAPE'] != 0]

# data.loc[(data['errors'] != 'median_LR_after') & (data['errors'] != 'median_Tree_after') &
#         (data['errors'] != 'median_LR_future') & (data['errors'] != 'median_Tree_future')]

fig = (
        p9.ggplot(data, p9.aes(x = 'errors', y ='MAPE', group='errors', colors='errors')) +
        p9.geom_boxplot( outlier_shape = True) +
#         p9.scale_y_continuous(limits =  (0, 50)) +        
        p9.stat_boxplot(geom ='errorbar')  +        
        p9.theme_bw() +
        p9.theme(figure_size = (8, 12)) +
        p9.facet_wrap('~line', ncol = 3) +
        p9.labs(title = 'MAPE of the lines in the day ' + select_day ) +
        p9.theme(figure_size = (9, 12)) +
        p9.theme(axis_text_x = p9.element_text(angle=90)) 
    )
p9.ggsave(fig, 'png/Boxplot' + '_' + select_day + '_60M_mean.png')  
p9.ggsave(fig, 'pdf/Boxplot' + '_' + select_day + '_60M_mean.pdf')  


for i in data['errors'].unique():
    print(i + ' : ' + str(data.loc[data['errors'] == i]['MAPE'].mean()))
# Out:
# Actual : 45.71495103280889
# After : 203.09006365767027
# Future : 211.89660631933498
